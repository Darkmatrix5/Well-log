# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('log_data/log.csv')
df
# Out:
#        Depth     RxoRt      RLL3        SP      RILD       MN       MI  \
# 0      195.0  226.0848    0.4076   69.8953  132.5052  -0.3548   0.1863
# 1      195.5  223.5031    0.4063   69.2303  123.6225  -0.3619   0.1867
# 2      196.0  221.4560    0.4047   68.4478  116.9258  -0.3668   0.1860
# 3      196.5  219.8248    0.4033   67.4843  111.7925  -0.3613   0.1867
# 4      197.0  218.1438    0.4023   66.3013  106.7821  -0.3569   0.1870
# ...      ...       ...       ...       ...       ...      ...      ...
# 8734  4806.0    1.1354  398.8031 -125.7813  412.4244  42.3643  46.5066
# 8735  4806.5    1.5895  487.2287 -126.0632  434.0304  41.9099  43.5448
# 8736  4807.0    4.1163  464.9174 -126.3459  454.8452  58.5249  57.1680
# 8737  4807.5    8.4264  353.6349 -126.6086  478.5475  69.1482  66.7409
# 8738  4808.0   12.6140  309.2645 -126.8335  506.5828  67.9119  66.1706
#
#         MCAL    DCAL    RHOB    RHOC     DPOR     CNLS       GR
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8739 entries, 0 to 8738
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Depth   8739 non-null   float64
#  1   RxoRt   8739 non-null   float64
#  2   RLL3    8739 non-null   float64
#  3   SP      8739 non-null   float64
#  4   RILD    8739 non-null   float64
#  5   MN      8739 non-null   float64
#  6   MI      8739 non-null   float64
#  7   MCAL    8739 non-null   float64
#  8   DCAL    8739 non-null   float64
#  9   RHOB    8739 non-null   float64
#  10  RHOC    8739 non-null   float64
#  11  DPOR    8739 non-null   float64
#  12  CNLS    8739 non-null   float64
#  13  GR      8739 non-null   float64
# dtypes: float64(14)
# memory usage: 956.0 KB

# %%
df.describe()
# Out:
#              Depth        RxoRt         RLL3           SP          RILD  \
# count  8739.000000  8739.000000  8739.000000  8739.000000   8739.000000
# mean   2535.727372   -18.493591    37.948919   -94.299762     34.511874
# std    1358.246302    31.420924    81.734581    39.652558    251.238360
# min     195.000000  -150.821900     0.389900  -201.623000      0.210400
# 25%    1292.250000   -31.993950     6.430800  -131.421100      4.356500
# 50%    2623.500000   -16.509300    12.138400   -95.587500      7.822900
# 75%    3715.750000    -5.941450    25.696300   -58.054000     19.486800
# max    4808.000000   247.583200   880.859400    69.895300  11510.641600
#
#                 MN           MI         MCAL         DCAL        RHOB  \
# count  8739.000000  8739.000000  8739.000000  8739.000000  8739.00000
# mean     11.714442    12.180632     5.906369     3.669944     2.03364
# std      27.537012    28.874862     1.305561     2.748873     0.41571
# ...

# %%
import seaborn as sns
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
fig,ax=plt.subplots(figsize=(4,8))

ax.plot(df['DCAL'],df['Depth'],label='Calliper')

ax.set_ylim(5000,0)
ax.legend(loc='upper right')
ax.grid()

# %%
fig,ax=plt.subplots(figsize=(4,8))

ax.plot(df['SP'],df['Depth'],label='SP')
ax.plot(df['GR'],df['Depth'],label='GR')

ax.axvline(x=-100,c='r')
ax.axhspan(3800,4800,alpha=0.2,color='grey',label='Shale Bed')

# calculating volume of shale using gamma ray loh
gr_max = max(df['GR'])
gr_min = min(df['GR'])

df['Vshale'] = (df['GR']-gr_min)*100/(gr_max-gr_min)
ax.plot(df['Vshale'],df['Depth'],label="Vshale")

ax.set_ylim(5000,0)
ax.legend(loc='upper right')
ax.grid()

# %%
fig,ax=plt.subplots(figsize=(4,10))

ax.plot(df['DPOR'],df['Depth'],label='Density_por')
ax.plot(df['CNLS'],df['Depth'],label='Neutrin_por')

ax.axhspan(1700,2500,alpha=0.2,color='yellow',label='expected Gas zone')
ax.axhspan(2500,3580,alpha=0.2,color='brown',label='expected Oil zone')

ax.set_ylim(5000,0)
ax.legend(loc='upper right')
ax.grid()

# %%
fig,ax=plt.subplots(figsize=(4,10))

ax.plot(df['RILD'],df['Depth'],label='RILD')
ax.plot(df['RLL3'],df['Depth'],label='RLL3')

ax.axhspan(1700,2500,alpha=0.2,color='yellow',label='expected Gas zone')
ax.axhspan(2500,3580,alpha=0.2,color='brown',label='expected Oil zone')

ax.set_ylim(5000,0)
ax.legend(loc='upper right')
ax.grid()

# %%
x = df['RILD']
x=np.array(x)
x[x>300]=300
# idx = np.argwhere(x > 1000)
y = df['RLL3']
y=np.array(y)
y[y>300]=300

# x = x.bfill()

# %%
fig,ax=plt.subplots(figsize=(4,10))

ax.plot(x,df['Depth'],label='RILD')
ax.plot(y,df['Depth'],label='RLL3')

ax.axhspan(1700,2400,alpha=0.2,color='yellow',label='expected Gas zone')
ax.axhspan(4100,4800,alpha=0.2,color='brown',label='expected Oil zone')

ax.set_ylim(5000,0)
# Out:
# (5000.0, 0.0)

# %%
fig,ax = plt.subplots(1,4,figsize=(12,8))

ax[0].plot(df['DCAL'],df['Depth'],label='Calliper')
ax[0].set_ylim(0,5000)
ax[0].legend(loc='upper right')
ax[0].grid()

ax[1].plot(df['SP'],df['Depth'],label='SP')
ax[1].plot(df['GR'],df['Depth'],label='GR')
ax[1].axvline(x=-100,c='r')
ax[1].axhspan(3800,4800,alpha=0.2,color='grey',label='Shale Bed')
ax[1].set_ylim(5000,0)
ax[1].legend(loc='upper right',prop = { "size": 6 })
ax[1].grid()

ax[2].plot(df['DPOR'],df['Depth'],label='Density_por')
ax[2].plot(df['CNLS'],df['Depth'],label='Neutrin_por')
ax[2].axhspan(1700,2500,alpha=0.2,color='#11FFF8',label='expected Gas zone')
ax[2].axhspan(2500,3580,alpha=0.2,color='#952803',label='expected Oil zone')
ax[2].set_ylim(5000,0)
ax[2].legend(loc='upper right',prop = { "size": 6 })
ax[2].grid()

ax[3].plot(x,df['Depth'],label='RILD')
ax[3].plot(y,df['Depth'],label='RLL3')
ax[3].axhspan(1700,2500,alpha=0.2,color='#11FFF8',label='High deep resistivity')
ax[3].axhspan(3800,4800,alpha=0.2,color='grey',label='high shallow resistivity')
ax[3].set_ylim(5000,0)
ax[3].legend(loc='upper right',prop = { "size": 6 })
ax[3].grid()
